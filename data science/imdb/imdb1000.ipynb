# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\SIMRAN\\Downloads\\imdb_1000.csv")
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df['genre'].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
df['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
crime_comedy = df[df['genre'].isin(['Crime','Comedy'])]

# %%
crime_comedy
# Out:
#      star_rating                     title content_rating   genre  duration  \
# 0            9.3  The Shawshank Redemption              R   Crime       142
# 1            9.2             The Godfather              R   Crime       175
# 2            9.1    The Godfather: Part II              R   Crime       200
# 4            8.9              Pulp Fiction              R   Crime       154
# 21           8.7               City of God              R   Crime       130
# ..           ...                       ...            ...     ...       ...
# 962          7.4        Driving Miss Daisy             PG  Comedy        99
# 969          7.4       Law Abiding Citizen              R   Crime       109
# 971          7.4        Death at a Funeral              R  Comedy        90
# 974          7.4                   Tootsie             PG  Comedy       116
# 978          7.4               Wall Street              R   Crime       126
#
#                                            actors_list
# ...

# %%
df[(df['genre']=='Comedy') | (df['genre']=='Crime')]
# Out:
#      star_rating                     title content_rating   genre  duration  \
# 0            9.3  The Shawshank Redemption              R   Crime       142
# 1            9.2             The Godfather              R   Crime       175
# 2            9.1    The Godfather: Part II              R   Crime       200
# 4            8.9              Pulp Fiction              R   Crime       154
# 21           8.7               City of God              R   Crime       130
# ..           ...                       ...            ...     ...       ...
# 962          7.4        Driving Miss Daisy             PG  Comedy        99
# 969          7.4       Law Abiding Citizen              R   Crime       109
# 971          7.4        Death at a Funeral              R  Comedy        90
# 974          7.4                   Tootsie             PG  Comedy       116
# 978          7.4               Wall Street              R   Crime       126
#
#                                            actors_list
# ...

# %%
df[(df['star_rating']>8.5) & (df['duration']<140) & ((df['genre']=='Adventure') | (df['genre']=='Comedy') | (df['genre']=='Action'))]
# Out:
#     star_rating                                           title  \
# 12          8.8  Star Wars: Episode V - The Empire Strikes Back
# 19          8.7                                       Star Wars
# 20          8.7                                      The Matrix
# 25          8.6                               Life Is Beautiful
# 29          8.6                                     City Lights
# 35          8.6                                    Modern Times
# 37          8.6                         Raiders of the Lost Ark
#
#    content_rating   genre  duration  \
# 12             PG  Action       124
# 19             PG  Action       121
# 20              R  Action       136
# 25          PG-13  Comedy       116
# 29         PASSED  Comedy        87
# 35              G  Comedy        87
# 37             PG  Action       115
#
#                                           actors_list
# 12  [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# ...

# %%
df[(df['star_rating']>8.5) & (df['duration']<140) & (df['genre'].isin(['Adventure','Action','Comedy']))]
# Out:
#     star_rating                                           title  \
# 12          8.8  Star Wars: Episode V - The Empire Strikes Back
# 19          8.7                                       Star Wars
# 20          8.7                                      The Matrix
# 25          8.6                               Life Is Beautiful
# 29          8.6                                     City Lights
# 35          8.6                                    Modern Times
# 37          8.6                         Raiders of the Lost Ark
#
#    content_rating   genre  duration  \
# 12             PG  Action       124
# 19             PG  Action       121
# 20              R  Action       136
# 25          PG-13  Comedy       116
# 29         PASSED  Comedy        87
# 35              G  Comedy        87
# 37             PG  Action       115
#
#                                           actors_list
# 12  [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# ...

# %%
df.groupby('genre')['star_rating','duration'].mean()
# Out:
# C:\Users\SIMRAN\AppData\Local\Temp\ipykernel_5664\2002660503.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('genre')['star_rating','duration'].mean()
#            star_rating    duration
# genre
# Action        7.884559  126.485294
# Adventure     7.933333  134.840000
# Animation     7.914516   96.596774
# Biography     7.862338  131.844156
# Comedy        7.822436  107.602564
# Crime         7.916935  122.298387
# Drama         7.902518  126.539568
# Family        7.850000  107.500000
# Fantasy       7.700000  112.000000
# Film-Noir     8.033333   97.333333
# History       8.000000   66.000000
# Horror        7.806897  102.517241
# Mystery       7.975000  115.625000
# Sci-Fi        7.920000  109.000000
# Thriller      7.680000  114.200000
# Western       8.255556  136.666667

# %%
movie = df[df['actors_list'].str.contains('Marlon Brando')]

# %%
movie
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 1            9.2             The Godfather              R  Crime       175
# 51           8.5            Apocalypse Now              R  Drama       153
# 122          8.3         On the Waterfront      NOT RATED  Crime       108
# 284          8.1  A Streetcar Named Desire             PG  Drama       122
#
#                                            actors_list
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 51   [u'Martin Sheen', u'Marlon Brando', u'Robert D...
# 122  [u'Marlon Brando', u'Karl Malden', u'Lee J. Co...
# 284  [u'Vivien Leigh', u'Marlon Brando', u'Kim Hunt...
